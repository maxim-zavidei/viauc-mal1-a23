# %% [markdown]
# # Group Project

# %% [markdown]
# ## 1. Frame the problem and look at the big picture

# %% [markdown]
# ## 2. Get the data

# %%
import pandas as pd
import numpy as np
owid_energy = pd.read_csv("owid-energy-data.csv")

print(owid_energy.info())
print(owid_energy.isna().sum())
percent_missing = owid_energy.isnull().sum() * 100 / len(owid_energy)
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', ascending = False, inplace = True)
print(missing_value_df)
owid_energy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22012 entries, 0 to 22011
# Columns: 129 entries, country to wind_share_energy
# dtypes: float64(126), int64(1), object(2)
# memory usage: 21.7+ MB
# None
# country                       0
# year                          0
# iso_code                   5500
# population                 3889
# gdp                       10899
#                           ...
# wind_elec_per_capita      14947
# wind_electricity          14016
# wind_energy_per_capita    17947
# wind_share_elec           15126
# wind_share_energy         17911
# Length: 129, dtype: int64
#                          percent_missing
# biofuel_cons_change_pct        92.063420
# solar_cons_change_pct          90.350718
# biofuel_cons_per_capita        89.542068
# wind_cons_change_pct           89.037798
# nuclear_cons_change_pct        88.792477
# ...                                  ...
# oil_prod_change_twh            22.097038
# oil_production                 20.929493
# ...

# %%
# Remove cols where more than 90% of data is NaN

#owid_energy = owid_energy.drop(['biofuel_cons_change_pct', 'biofuel_cons_per_capita', 'biofuel_cons_change_twh', 'biofuel_share_energy', 'biofuel_consumption', 'solar_cons_change_pct', 'wind_cons_change_pct', 'nuclear_cons_change_pct' ,'other_renewables_cons_change_pct', 'nuclear_energy_per_capita', 'nuclear_share_energy', 'electricity_share_energy', 'solar_energy_per_capita', 'solar_share_energy', 'wind_energy_per_capita', 'wind_share_energy', 'fossil_energy_per_capita', 'nuclear_cons_change_twh', 'other_renewables_energy_per_capita', 'other_renewables_share_energy'], axis=1)
percent_missing = owid_energy.isnull().sum() * 100 / len(owid_energy)
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', ascending = False, inplace = True)
print(missing_value_df)
owid_energy
owid_energy.drop(['country', 'iso_code'],axis=1).corr()
# Out:
#                          percent_missing
# biofuel_cons_change_pct        92.063420
# solar_cons_change_pct          90.350718
# biofuel_cons_per_capita        89.542068
# wind_cons_change_pct           89.037798
# nuclear_cons_change_pct        88.792477
# ...                                  ...
# oil_prod_change_twh            22.097038
# oil_production                 20.929493
# population                     17.667636
# year                            0.000000
# country                         0.000000
#
# [129 rows x 1 columns]
#                              year  population       gdp  \
# year                     1.000000    0.040486  0.085729
# population               0.040486    1.000000  0.859094
# gdp                      0.085729    0.859094  1.000000
# biofuel_cons_change_pct -0.005243   -0.052764 -0.034401
# biofuel_cons_change_twh  0.125551    0.419092  0.621666
# ...                           ...         ...       ...
# ...

# %%
owid_energy
# Out:
#              country iso_code           gdp  biofuel_cons_change_pct  \
# 0      ASEAN (Ember)      NaN           NaN                      NaN
# 1      ASEAN (Ember)      NaN           NaN                      NaN
# 2      ASEAN (Ember)      NaN           NaN                      NaN
# 3      ASEAN (Ember)      NaN           NaN                      NaN
# 4      ASEAN (Ember)      NaN           NaN                      NaN
# ...              ...      ...           ...                      ...
# 22007       Zimbabwe      ZWE  2.271535e+10                      NaN
# 22008       Zimbabwe      ZWE           NaN                      NaN
# 22009       Zimbabwe      ZWE           NaN                      NaN
# 22010       Zimbabwe      ZWE           NaN                      NaN
# 22011       Zimbabwe      ZWE           NaN                      NaN
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# ...

# %%
cleaned_data = owid_energy[['country', 'year', 'population', 'oil_production', 'oil_prod_change_twh', 'gas_production', 'gas_prod_change_twh','coal_production', 'coal_prod_change_twh', 'oil_prod_per_capita', 'gas_prod_per_capita', 'coal_prod_per_capita']]
owid_energy = owid_energy.drop(['year', 'population', 'oil_production', 'oil_prod_change_twh', 'gas_production', 'gas_prod_change_twh', 'coal_production', 'coal_prod_change_twh', 'oil_prod_per_capita', 'gas_prod_per_capita', 'coal_prod_per_capita'], axis=1)
percent_missing = owid_energy.isnull().sum() * 100 / len(owid_energy)
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', ascending = False, inplace = True)
print(missing_value_df)
cleaned_data = cleaned_data.dropna()
cleaned_data
# Out:
#                             percent_missing
# biofuel_cons_change_pct           92.063420
# solar_cons_change_pct             90.350718
# biofuel_cons_per_capita           89.542068
# wind_cons_change_pct              89.037798
# nuclear_cons_change_pct           88.792477
# ...                                     ...
# energy_cons_change_pct            44.952753
# energy_cons_change_twh            44.075959
# primary_energy_consumption        42.813011
# iso_code                          24.986371
# country                            0.000000
#
# [118 rows x 1 columns]
#            country  year  population  oil_production  oil_prod_change_twh  \
# 104    Afghanistan  1981  11155196.0             0.0                  0.0
# 105    Afghanistan  1982  10088290.0             0.0                  0.0
# 106    Afghanistan  1983   9951447.0             0.0                  0.0
# 107    Afghanistan  1984  10243689.0             0.0                  0.0
# ...

# %%
cleaned_data.drop(['country'], axis=1).corr()
# Out:
#                           year  population  oil_production  \
# year                  1.000000    0.001643        0.093514
# population            0.001643    1.000000        0.866051
# oil_production        0.093514    0.866051        1.000000
# oil_prod_change_twh  -0.010690    0.301161        0.339766
# gas_production        0.114592    0.779763        0.944255
# gas_prod_change_twh   0.045637    0.532761        0.604767
# coal_production       0.023165    0.873854        0.876727
# coal_prod_change_twh  0.013305    0.384406        0.319452
# oil_prod_per_capita   0.101254   -0.033563        0.045845
# gas_prod_per_capita   0.112232   -0.023249        0.026562
# coal_prod_per_capita -0.075217    0.041894        0.081081
#
#                       oil_prod_change_twh  gas_production  \
# year                            -0.010690        0.114592
# population                       0.301161        0.779763
# oil_production                   0.339766        0.944255
# ...
